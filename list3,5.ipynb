# %% [markdown]
# <a href="https://colab.research.google.com/github/canon0826/Python_training/blob/main/list3%2C5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    "予想価格" : [240,250,150,240,300,5000]
}
df = pd.DataFrame(data)
df
# Out:
#    予想価格
# 0   240
# 1   250
# 2   150
# 3   240
# 4   300
# 5  5000

# %%
print(df.mean())
# Out:
# 予想価格    1030.0
# dtype: float64
