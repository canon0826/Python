# %% [markdown]
# <a href="https://colab.research.google.com/github/canon0826/Python_training/blob/main/list2%2C5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# DataFrame = pd.read_csv(ファイル名.csv)

# %%
import pandas as pd
df = pd.read_csv("test.csv")
df
# Out:
#    名前   国語  数学  英語    番号
# 0  A太   83  89  76  A001
# 1  B介   66  93  75  B001
# 2  C子  100  84  96  B002
# 3  D郎   60  73  40  A002
# 4  E美   92  62  84  C001
# 5  F菜   96  92  94  C002
