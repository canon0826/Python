# %% [markdown]
# <a href="https://colab.research.google.com/github/canon0826/Python_training/blob/main/list2%2C3_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = [
        [60,65,66],
        [80,85,88],
        [100,100,100]
]
col = ["国語","数学","英語"]
idx = ["花子","太郎","山田"]
df = pd.DataFrame(data, columns=col, index=idx)
df
# Out:
#      国語   数学   英語
# 花子   60   65   66
# 太郎   80   85   88
# 山田  100  100  100
